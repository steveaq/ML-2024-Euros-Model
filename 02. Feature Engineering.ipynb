# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data/data_rank.csv")

# %%
def result_finder(home, away):
    if home > away:
        return pd.Series([0, 3, 0])
    if home < away:
        return pd.Series([1, 0, 3])
    else:
        return pd.Series([2, 1, 1])

results = df.apply(lambda x: result_finder(x["home_score"], x["away_score"]), axis=1)

# %%
df[["result", "home_team_points", "away_team_points"]] = results

# %%
import seaborn as sns

sns.heatmap(df[["total_points_home", "rank_home", "total_points_away", "rank_away"]].corr())
# Out:
# <AxesSubplot:>

# %%
df["rank_dif"] = df["rank_home"] - df["rank_away"]
df["sg"] = df["home_score"] - df["away_score"]
df["points_home_by_rank"] = df["home_team_points"]/df["rank_away"]
df["points_away_by_rank"] = df["away_team_points"]/df["rank_home"]

# %%
home_team = df[["date", "home_team", "home_score", "away_score", "rank_home", "rank_away","rank_change_home", "total_points_home", "result", "rank_dif", "points_home_by_rank", "home_team_points"]]

away_team = df[["date", "away_team", "away_score", "home_score", "rank_away", "rank_home","rank_change_away", "total_points_away", "result", "rank_dif", "points_away_by_rank", "away_team_points"]]

# %%
home_team.columns = [h.replace("home_", "").replace("_home", "").replace("away_", "suf_").replace("_away", "_suf") for h in home_team.columns]

away_team.columns = [a.replace("away_", "").replace("_away", "").replace("home_", "suf_").replace("_home", "_suf") for a in away_team.columns]

# %%
team_stats = home_team.append(away_team)#.sort_values("date")

# %%
team_stats
# Out:
#             date                    team  score  suf_score   rank  rank_suf  \
# 0     2019-09-29              Bangladesh    4.0        1.0  187.0     185.0
# 1     2019-09-30                Botswana    0.0        0.0  148.0     152.0
# 2     2019-10-02                  Mexico    2.0        0.0   12.0     100.0
# 3     2019-10-03              Bangladesh    2.0        0.0  187.0     185.0
# 4     2019-10-05                  Jordan    0.0        0.0   98.0     157.0
# 5     2019-10-05                Malaysia    6.0        0.0  158.0     202.0
# 6     2019-10-09                 Liberia    1.0        0.0  152.0     177.0
# 7     2019-10-09             South Sudan    2.0        1.0  173.0     198.0
# 8     2019-10-09                 Bahrain    2.0        3.0  105.0     109.0
# 9     2019-10-09                 Germany    2.0        2.0   16.0      10.0
# 10    2019-10-10                 Belarus    0.0        0.0   82.0     102.0
# 11    2019-10-10             Netherlands    3.0        1.0   13.0      33.0
# 12    2019-10-10                 Croatia    3.0        0.0    8.0      50.0
# 13    2019-10-10                Slovakia    1.0        1.0   29.0      23.0
# 14    2019-10-10                 Austria    3.0        1.0   27.0      86.0
# 15    2019-10-10         North Macedonia    2.0        1.0   69.0      58.0
# 16    2019-10-10                  Latvia    0.0        3.0  139.0      22.0
# 17    2019-10-10              Kazakhstan    1.0        2.0  116.0      92.0
# 18    2019-10-10                 Belgium    9.0        0.0    1.0     210.0
# 19    2019-10-10                  Russia    4.0        0.0   42.0      52.0
# 20    2019-10-10                  Brazil    1.0        1.0    3.0      20.0
# 21    2019-10-10                   Gabon    1.0        0.0   88.0      61.0
# 22    2019-10-10                  Kosovo    1.0        0.0  119.0     197.0
# 23    2019-10-10                   Niger    1.0        1.0  107.0      81.0
# 24    2019-10-10                  Serbia    1.0        0.0   35.0      40.0
# 25    2019-10-10                Thailand    1.0        1.0  114.0      90.0
# 26    2019-10-10               Venezuela    4.0        1.0   26.0      72.0
# 27    2019-10-10     Trinidad and Tobago    0.0        2.0  100.0      67.0
# 28    2019-10-10                   Haiti    1.0        1.0   86.0      43.0
# 29    2019-10-10  British Virgin Islands    0.0        4.0  203.0     208.0
# ...          ...                     ...    ...        ...    ...       ...
# 3783  2024-06-11                  Cyprus    4.0        1.0  125.0     210.0
# 3784  2024-06-11                   Sudan    3.0        0.0  127.0     166.0
# 3785  2024-06-11                  Rwanda    1.0        0.0  133.0     148.0
# 3786  2024-06-11                Zimbabwe    1.0        3.0  124.0      58.0
# 3787  2024-06-11                Eswatini    1.0        2.0  149.0     177.0
# 3788  2024-06-11                Cameroon    1.0        1.0   51.0      93.0
# 3789  2024-06-11                Tanzania    1.0        0.0  119.0      87.0
# 3790  2024-06-11                   Congo    0.0        6.0  112.0      12.0
# 3791  2024-06-11                 Burundi    3.0        1.0  140.0     199.0
# 3792  2024-06-11                    Mali    0.0        0.0   47.0     109.0
# 3793  2024-06-11                 Comoros    2.0        0.0  121.0     181.0
# 3794  2024-06-11             Afghanistan    0.0        1.0  158.0     137.0
# 3795  2024-06-11                   India    1.0        2.0  117.0      37.0
# 3796  2024-06-11                   Syria    0.0        5.0   89.0      18.0
# 3797  2024-06-11               Singapore    1.0        3.0  156.0     101.0
# 3798  2024-06-11                China PR    0.0        1.0   88.0      22.0
# 3799  2024-06-11               Hong Kong    0.0        0.0  154.0     141.0
# 3800  2024-06-11              Uzbekistan    0.0        0.0   66.0      20.0
# 3801  2024-06-11             Philippines    0.0        2.0  139.0     142.0
# 3802  2024-06-11                 Vietnam    1.0        3.0  105.0      59.0
# 3803  2024-06-11                Pakistan    0.0        3.0  195.0      99.0
# 3804  2024-06-11                  Jordan    2.0        1.0   70.0      53.0
# 3805  2024-06-11                 Bahrain    1.0        1.0   82.0      69.0
# 3806  2024-06-11                   Nepal    2.0        2.0  175.0     151.0
# 3807  2024-06-11              Bangladesh    0.0        4.0  183.0     115.0
# 3808  2024-06-11               Palestine    0.0        5.0   97.0      23.0
# 3809  2024-06-11          Cayman Islands    0.0        3.0  197.0     169.0
# 3810  2024-06-11                  Belize    1.0        3.0  182.0     157.0
# 3811  2024-06-11  British Virgin Islands    0.0        4.0  207.0     150.0
# 3812  2024-06-11                Anguilla    0.0        8.0  209.0     160.0
#
#       rank_change  total_points  result  rank_dif  points_by_rank  team_points
# 0             5.0        912.00       0       2.0        0.016216            3
# 1             1.0       1059.00       2      -4.0        0.006579            1
# 2             0.0       1603.00       0     -88.0        0.030000            3
# 3             5.0        912.00       0       2.0        0.016216            3
# 4            -1.0       1235.00       2     -59.0        0.006369            1
# 5            -1.0       1015.00       0     -44.0        0.014851            3
# 6             0.0       1053.00       0     -25.0        0.016949            3
# 7             4.0        977.00       0     -25.0        0.015152            3
# 8            -4.0       1206.00       1      -4.0        0.000000            0
# 9             1.0       1580.00       2       6.0        0.100000            1
# 10           -2.0       1294.00       2     -20.0        0.009804            1
# 11           -3.0       1586.00       0     -20.0        0.090909            3
# 12            1.0       1625.00       0     -42.0        0.060000            3
# 13           -2.0       1493.00       2       6.0        0.043478            1
# 14            0.0       1503.00       0     -59.0        0.034884            3
# 15           -2.0       1339.00       0      11.0        0.051724            3
# 16            5.0       1075.00       1     117.0        0.000000            0
# 17            4.0       1169.00       1      24.0        0.000000            0
# 18            0.0       1752.00       0    -209.0        0.014286            3
# 19           -4.0       1455.00       0     -10.0        0.057692            3
# 20            1.0       1719.00       2     -17.0        0.050000            1
# 21           -2.0       1272.00       0      27.0        0.049180            3
# 22           -1.0       1164.00       0     -78.0        0.015228            3
# 23            3.0       1201.00       2      26.0        0.012346            1
# 24            0.0       1476.00       0      -5.0        0.075000            3
# 25           -1.0       1175.00       2      24.0        0.011111            1
# 26            0.0       1506.00       0     -46.0        0.041667            3
# 27           -1.0       1226.00       1      33.0        0.000000            0
# 28            3.0       1277.00       2      43.0        0.023256            1
# 29           -1.0        867.00       1      -5.0        0.000000            0
# ...           ...           ...     ...       ...             ...          ...
# 3783          0.0       1143.42       1      85.0        0.014286            3
# 3784         -1.0       1128.74       1      39.0        0.018072            3
# 3785          0.0       1107.04       1      15.0        0.020270            3
# 3786          0.0       1144.56       0     -66.0        0.000000            0
# 3787          0.0       1045.88       0      28.0        0.000000            0
# 3788          5.0       1452.59       2      42.0        0.010753            1
# 3789         -2.0       1160.98       1     -32.0        0.034483            3
# 3790          0.0       1179.80       0    -100.0        0.000000            0
# 3791          1.0       1085.83       1      59.0        0.015075            3
# 3792         -4.0       1469.81       2      62.0        0.009174            1
# 3793          2.0       1156.45       1      60.0        0.016575            3
# 3794          0.0       1017.68       0     -21.0        0.000000            0
# 3795         15.0       1165.17       0     -80.0        0.000000            0
# 3796         -2.0       1265.51       0     -71.0        0.000000            0
# 3797          0.0       1020.50       0     -55.0        0.000000            0
# 3798          9.0       1273.78       0     -66.0        0.000000            0
# 3799          4.0       1022.91       2     -13.0        0.007092            1
# 3800         -2.0       1376.50       2     -46.0        0.050000            1
# 3801         -1.0       1086.17       0       3.0        0.000000            0
# 3802         11.0       1194.58       0     -46.0        0.000000            0
# 3803          0.0        856.54       0     -96.0        0.000000            0
# 3804        -17.0       1343.60       1     -17.0        0.056604            3
# 3805         -4.0       1297.32       2     -13.0        0.014493            1
# 3806          0.0        948.05       2     -24.0        0.006623            1
# 3807          0.0        916.75       0     -68.0        0.000000            0
# 3808         -2.0       1227.20       0     -74.0        0.000000            0
# 3809          0.0        851.19       0     -28.0        0.000000            0
# 3810          0.0        918.68       0     -25.0        0.000000            0
# 3811          0.0        807.57       0     -57.0        0.000000            0
# 3812          0.0        785.69       0     -49.0        0.000000            0
#
# [7626 rows x 12 columns]

# %%
stats_val = []

for index, row in team_stats.iterrows():
    team = row["team"]
    date = row["date"]
    past_games = team_stats.loc[(team_stats["team"] == team) & (team_stats["date"] < date)].sort_values(by=['date'], ascending=False)
    last5 = past_games.head(5)
    
    goals = past_games["score"].mean()
    goals_l5 = last5["score"].mean()
    
    goals_suf = past_games["suf_score"].mean()
    goals_suf_l5 = last5["suf_score"].mean()
    
    rank = past_games["rank_suf"].mean()
    rank_l5 = last5["rank_suf"].mean()
    
    if len(last5) > 0:
        points = past_games["total_points"].values[0] - past_games["total_points"].values[-1]#qtd de pontos ganhos
        points_l5 = last5["total_points"].values[0] - last5["total_points"].values[-1] 
    else:
        points = 0
        points_l5 = 0
        
    gp = past_games["team_points"].mean()
    gp_l5 = last5["team_points"].mean()
    
    gp_rank = past_games["points_by_rank"].mean()
    gp_rank_l5 = last5["points_by_rank"].mean()
    
    stats_val.append([goals, goals_l5, goals_suf, goals_suf_l5, rank, rank_l5, points, points_l5, gp, gp_l5, gp_rank, gp_rank_l5])

# %%
stats_mean = ["goals_mean", "goals_mean_l5", "goals_suf_mean", "goals_suf_mean_l5", "rank_mean", "rank_mean_l5", "points_mean", "points_mean_l5", "game_points_mean", "game_points_mean_l5", "game_points_rank_mean", "game_points_rank_mean_l5"]

# %%
stats_df = pd.DataFrame(stats_val, columns=stats_mean)

full_df = pd.concat([team_stats.reset_index(drop=True), stats_df], axis=1, ignore_index=False)

# %%
home_team_stats = full_df.iloc[:int(full_df.shape[0]/2),:]
away_team_stats = full_df.iloc[int(full_df.shape[0]/2):,:]

# %%
home_team_stats = home_team_stats[home_team_stats.columns[-12:]]
away_team_stats = away_team_stats[away_team_stats.columns[-12:]]

# %%
home_team_stats.columns = ['home_'+str(col) for col in home_team_stats.columns]
away_team_stats.columns = ['away_'+str(col) for col in away_team_stats.columns]

# %%
match_stats = pd.concat([home_team_stats, away_team_stats.reset_index(drop=True)], axis=1, ignore_index=False)

# %%
full_df = pd.concat([df, match_stats.reset_index(drop=True)], axis=1, ignore_index=False)

# %%
def find_friendly(x):
    if x == "Friendly":
        return 1
    else: return 0

full_df["is_friendly"] = full_df["tournament"].apply(lambda x: find_friendly(x))

# %%
full_df = pd.get_dummies(full_df, columns=["is_friendly"])

# %%
base_df = full_df[["date", "home_team", "away_team", "rank_home", "rank_away","home_score", "away_score","result", "rank_dif", "rank_change_home", "rank_change_away", 'home_goals_mean',
       'home_goals_mean_l5', 'home_goals_suf_mean', 'home_goals_suf_mean_l5',
       'home_rank_mean', 'home_rank_mean_l5', 'home_points_mean',
       'home_points_mean_l5', 'away_goals_mean', 'away_goals_mean_l5',
       'away_goals_suf_mean', 'away_goals_suf_mean_l5', 'away_rank_mean',
       'away_rank_mean_l5', 'away_points_mean', 'away_points_mean_l5','home_game_points_mean', 'home_game_points_mean_l5',
       'home_game_points_rank_mean', 'home_game_points_rank_mean_l5','away_game_points_mean',
       'away_game_points_mean_l5', 'away_game_points_rank_mean',
       'away_game_points_rank_mean_l5',
       'is_friendly_0', 'is_friendly_1']]

# %%
base_df_no_fg = base_df.dropna()

# %%
base_df_no_fg.to_csv("data/full_db.csv", index=False)

# %%
df = base_df_no_fg.copy()

# %%
df['total_games_away'] = df.apply(lambda x: len(df[(df.home_team == x["away_team"]) & (df.date < x["date"])])+len(df[(df.away_team == x["away_team"]) & (df.date < x["date"])]), axis=1)

# %%
df['total_games_home'] = df.apply(lambda x: len(df[(df.home_team == x["home_team"]) & (df.date < x["date"])])+len(df[(df.away_team == x["home_team"]) & (df.date < x["date"])]), axis=1)

# %%
df = df[df.rank_home != df.rank_away]

# %%
df['home_weight_goals'] = df.apply(lambda x: (x["home_goals_mean"]*x["rank_dif"]), axis =1)

# %%
df['away_weight_goals_suf'] = df.apply(lambda x: (x["away_goals_suf_mean"]*x["rank_dif"]), axis =1)

# %%
df['home_weight_goals_l5'] = df.apply(lambda x: (x["home_goals_mean_l5"]*x["rank_dif"]), axis =1)

# %%
df['away_weight_goals_suf_l5'] = df.apply(lambda x: (x["away_goals_suf_mean_l5"]*x["rank_dif"]), axis =1)

# %%
df['home_weight_points'] = df.apply(lambda x: (x["home_game_points_mean"]*x["rank_dif"]), axis =1)

# %%
df['away_weight_points'] = df.apply(lambda x: (x["away_game_points_mean"]*x["rank_dif"]), axis =1)

# %%
df['away_weight_goals'] = df.apply(lambda x: (x["away_goals_mean"]*x["rank_dif"]), axis =1)
df['home_weight_goals_suf'] = df.apply(lambda x: (x["home_goals_suf_mean"]*x["rank_dif"]), axis =1)

# %%
df['away_weight_goals_l5'] = df.apply(lambda x: (x["away_goals_mean_l5"]*x["rank_dif"]), axis =1)
df['home_weight_goals_suf_l5'] = df.apply(lambda x: (x["home_goals_suf_mean_l5"]*x["rank_dif"]), axis =1)

# %%
df.to_csv("data/new_model.csv", index=False)

# %%
df_model = df[(df.total_games_home > 5) & (df.total_games_away > 5)]

# %%
df_model.corr()
# Out:
#                                rank_home  rank_away  home_score  away_score  \
# rank_home                       1.000000   0.434335   -0.241476    0.267769
# rank_away                       0.434335   1.000000    0.263715   -0.209504
# home_score                     -0.241476   0.263715    1.000000   -0.203761
# away_score                      0.267769  -0.209504   -0.203761    1.000000
# result                          0.157417  -0.179347   -0.531658    0.267532
# rank_dif                        0.540566  -0.523017   -0.474803    0.449048
# rank_change_home                0.016159  -0.005684   -0.025193    0.040412
# rank_change_away               -0.002367  -0.004487    0.017813    0.019637
# home_goals_mean                -0.638373  -0.234422    0.273094   -0.209814
# home_goals_mean_l5             -0.423104  -0.111132    0.214727   -0.151408
# home_goals_suf_mean             0.695654   0.241106   -0.212318    0.300173
# home_goals_suf_mean_l5          0.493026   0.139012   -0.185449    0.259058
# home_rank_mean                  0.745649   0.486964   -0.134478    0.132610
# home_rank_mean_l5               0.630424   0.448505   -0.084591    0.104295
# home_points_mean               -0.445571  -0.168518    0.191311   -0.141660
# home_points_mean_l5            -0.186449  -0.077359    0.106089   -0.119829
# away_goals_mean                -0.208353  -0.600088   -0.206244    0.229767
# away_goals_mean_l5             -0.089601  -0.390787   -0.169426    0.194626
# away_goals_suf_mean             0.261044   0.659048    0.265940   -0.171027
# away_goals_suf_mean_l5          0.168293   0.453418    0.206082   -0.133906
# away_rank_mean                  0.464133   0.756462    0.156771   -0.118841
# away_rank_mean_l5               0.448316   0.658509    0.110210   -0.075779
# away_points_mean               -0.150073  -0.393369   -0.137678    0.136517
# away_points_mean_l5            -0.038474  -0.161521   -0.093473    0.064824
# home_game_points_mean          -0.752094  -0.256620    0.263224   -0.266015
# home_game_points_mean_l5       -0.508703  -0.143005    0.220528   -0.217560
# home_game_points_rank_mean     -0.656467  -0.328735    0.201384   -0.157613
# home_game_points_rank_mean_l5  -0.422815  -0.205933    0.133386   -0.110320
# away_game_points_mean          -0.247939  -0.708115   -0.241594    0.218877
# away_game_points_mean_l5       -0.125988  -0.462132   -0.198162    0.178475
# away_game_points_rank_mean     -0.319744  -0.670219   -0.166699    0.188877
# away_game_points_rank_mean_l5  -0.215801  -0.424804   -0.111736    0.111157
# is_friendly_0                   0.054856  -0.041448   -0.031263    0.080489
# is_friendly_1                  -0.054856   0.041448    0.031263   -0.080489
# total_games_away               -0.125197  -0.306551   -0.079890    0.106059
# total_games_home               -0.280947  -0.111097    0.099405   -0.049584
# home_weight_goals               0.481315  -0.481263   -0.495924    0.378966
# away_weight_goals_suf           0.421999  -0.538683   -0.473400    0.376815
# home_weight_goals_l5            0.447927  -0.446591   -0.458419    0.350432
# away_weight_goals_suf_l5        0.412354  -0.504135   -0.450535    0.362127
# home_weight_points              0.480623  -0.499230   -0.490162    0.378314
# away_weight_points              0.530865  -0.445563   -0.403833    0.448022
# away_weight_goals               0.509974  -0.445710   -0.396206    0.454406
# home_weight_goals_suf           0.536533  -0.418371   -0.383013    0.459494
# away_weight_goals_l5            0.479948  -0.414676   -0.371386    0.424451
# home_weight_goals_suf_l5        0.502666  -0.399476   -0.356446    0.432623
#
#                                  result  rank_dif  rank_change_home  \
# rank_home                      0.157417  0.540566          0.016159
# rank_away                     -0.179347 -0.523017         -0.005684
# home_score                    -0.531658 -0.474803         -0.025193
# away_score                     0.267532  0.449048          0.040412
# result                         1.000000  0.316464          0.040521
# rank_dif                       0.316464  1.000000          0.020600
# rank_change_home               0.040521  0.020600          1.000000
# rank_change_away              -0.007080  0.001951         -0.062396
# home_goals_mean               -0.177560 -0.385100         -0.088782
# home_goals_mean_l5            -0.140153 -0.296559         -0.126997
# home_goals_suf_mean            0.156335  0.433059          0.076331
# home_goals_suf_mean_l5         0.125886  0.336681          0.173518
# home_rank_mean                 0.081396  0.250736         -0.062010
# home_rank_mean_l5              0.064951  0.177626         -0.038308
# home_points_mean              -0.125000 -0.264219         -0.171389
# home_points_mean_l5           -0.067157 -0.104171         -0.350499
# away_goals_mean                0.146808  0.363331          0.008197
# away_goals_mean_l5             0.121779  0.280211          0.022582
# away_goals_suf_mean           -0.160516 -0.368541          0.012179
# away_goals_suf_mean_l5        -0.124557 -0.264248          0.015632
# away_rank_mean                -0.105212 -0.267357         -0.038824
# away_rank_mean_l5             -0.065272 -0.190835         -0.037514
# away_points_mean               0.102662  0.225402          0.004245
# away_points_mean_l5            0.088663  0.114455          0.002165
# home_game_points_mean         -0.178282 -0.471974         -0.116512
# home_game_points_mean_l5      -0.143090 -0.347787         -0.243561
# home_game_points_rank_mean    -0.123950 -0.314133         -0.020957
# home_game_points_rank_mean_l5 -0.071067 -0.207740         -0.094286
# away_game_points_mean          0.166347  0.426770          0.001462
# away_game_points_mean_l5       0.143527  0.312417          0.018606
# away_game_points_rank_mean     0.129799  0.323431          0.021056
# away_game_points_rank_mean_l5  0.085547  0.192568          0.022712
# is_friendly_0                  0.026736  0.090619          0.003050
# is_friendly_1                 -0.026736 -0.090619         -0.003050
# total_games_away               0.058455  0.167853          0.013739
# total_games_home              -0.060267 -0.162077         -0.022452
# home_weight_goals              0.325941  0.904936          0.024621
# away_weight_goals_suf          0.298994  0.902440          0.009750
# home_weight_goals_l5           0.303301  0.840960          0.036830
# away_weight_goals_suf_l5       0.290402  0.861045         -0.001544
# home_weight_points             0.327459  0.921063          0.031411
# away_weight_points             0.277453  0.918479          0.021780
# away_weight_goals              0.264672  0.898848          0.019638
# home_weight_goals_suf          0.240959  0.898444          0.008700
# away_weight_goals_l5           0.248603  0.841451          0.017961
# home_weight_goals_suf_l5       0.225213  0.848751          0.001375
#
#                                rank_change_away  home_goals_mean  \
# rank_home                             -0.002367        -0.638373
# rank_away                             -0.004487        -0.234422
# home_score                             0.017813         0.273094
# away_score                             0.019637        -0.209814
# result                                -0.007080        -0.177560
# rank_dif                               0.001951        -0.385100
# rank_change_home                      -0.062396        -0.088782
# rank_change_away                       1.000000        -0.009581
# home_goals_mean                       -0.009581         1.000000
# home_goals_mean_l5                     0.016512         0.686040
# home_goals_suf_mean                    0.027290        -0.600746
# home_goals_suf_mean_l5                 0.022695        -0.445678
# home_rank_mean                        -0.022812        -0.248259
# home_rank_mean_l5                     -0.009172        -0.243432
# home_points_mean                      -0.016995         0.544696
# home_points_mean_l5                    0.011451         0.285615
# away_goals_mean                       -0.070199         0.205638
# away_goals_mean_l5                    -0.149226         0.113769
# away_goals_suf_mean                    0.051441        -0.173163
# away_goals_suf_mean_l5                 0.142546        -0.112222
# away_rank_mean                        -0.051247        -0.148487
# away_rank_mean_l5                     -0.031806        -0.163057
# away_points_mean                      -0.161472         0.123277
# away_points_mean_l5                   -0.344954         0.032895
# home_game_points_mean                 -0.021574         0.851267
# home_game_points_mean_l5               0.001218         0.612473
# home_game_points_rank_mean             0.006826         0.547958
# home_game_points_rank_mean_l5          0.018217         0.364482
# away_game_points_mean                 -0.091907         0.209244
# away_game_points_mean_l5              -0.247325         0.106203
# away_game_points_rank_mean            -0.005601         0.174673
# away_game_points_rank_mean_l5         -0.075776         0.112681
# is_friendly_0                          0.006859        -0.051567
# is_friendly_1                         -0.006859         0.051567
# total_games_away                      -0.017299         0.019605
# total_games_home                      -0.022512         0.127243
# home_weight_goals                     -0.010805        -0.408797
# away_weight_goals_suf                  0.006245        -0.289283
# home_weight_goals_l5                  -0.012810        -0.388589
# away_weight_goals_suf_l5               0.001973        -0.284052
# home_weight_points                    -0.006628        -0.369824
# away_weight_points                    -0.001854        -0.401978
# away_weight_goals                      0.004756        -0.385264
# home_weight_goals_suf                  0.016219        -0.368315
# away_weight_goals_l5                   0.005851        -0.359938
# home_weight_goals_suf_l5               0.025041        -0.344274
#
#                                home_goals_mean_l5            ...             \
# rank_home                               -0.423104            ...
# rank_away                               -0.111132            ...
# home_score                               0.214727            ...
# away_score                              -0.151408            ...
# result                                  -0.140153            ...
# rank_dif                                -0.296559            ...
# rank_change_home                        -0.126997            ...
# rank_change_away                         0.016512            ...
# home_goals_mean                          0.686040            ...
# home_goals_mean_l5                       1.000000            ...
# home_goals_suf_mean                     -0.399083            ...
# home_goals_suf_mean_l5                  -0.410055            ...
# home_rank_mean                          -0.148109            ...
# home_rank_mean_l5                        0.069809            ...
# home_points_mean                         0.357737            ...
# home_points_mean_l5                      0.332386            ...
# away_goals_mean                          0.124947            ...
# away_goals_mean_l5                       0.106933            ...
# away_goals_suf_mean                     -0.079540            ...
# away_goals_suf_mean_l5                  -0.057243            ...
# away_rank_mean                          -0.047140            ...
# away_rank_mean_l5                       -0.020521            ...
# away_points_mean                         0.059524            ...
# away_points_mean_l5                      0.013311            ...
# home_game_points_mean                    0.584290            ...
# home_game_points_mean_l5                 0.749818            ...
# home_game_points_rank_mean               0.354474            ...
# home_game_points_rank_mean_l5            0.226562            ...
# away_game_points_mean                    0.117731            ...
# away_game_points_mean_l5                 0.085868            ...
# away_game_points_rank_mean               0.089973            ...
# away_game_points_rank_mean_l5            0.054076            ...
# is_friendly_0                           -0.010227            ...
# is_friendly_1                            0.010227            ...
# total_games_away                         0.037039            ...
# total_games_home                         0.112571            ...
# home_weight_goals                       -0.323795            ...
# away_weight_goals_suf                   -0.228507            ...
# home_weight_goals_l5                    -0.398900            ...
# away_weight_goals_suf_l5                -0.222016            ...
# home_weight_points                      -0.292821            ...
# away_weight_points                      -0.308310            ...
# away_weight_goals                       -0.293821            ...
# home_weight_goals_suf                   -0.275052            ...
# away_weight_goals_l5                    -0.275356            ...
# home_weight_goals_suf_l5                -0.253169            ...
#
#                                home_weight_goals  away_weight_goals_suf  \
# rank_home                               0.481315               0.421999
# rank_away                              -0.481263              -0.538683
# home_score                             -0.495924              -0.473400
# away_score                              0.378966               0.376815
# result                                  0.325941               0.298994
# rank_dif                                0.904936               0.902440
# rank_change_home                        0.024621               0.009750
# rank_change_away                       -0.010805               0.006245
# home_goals_mean                        -0.408797              -0.289283
# home_goals_mean_l5                     -0.323795              -0.228507
# home_goals_suf_mean                     0.356411               0.338487
# home_goals_suf_mean_l5                  0.269640               0.261348
# home_rank_mean                          0.247942               0.206344
# home_rank_mean_l5                       0.177693               0.144190
# home_points_mean                       -0.270031              -0.187736
# home_points_mean_l5                    -0.111677              -0.076775
# away_goals_mean                         0.350024               0.366982
# away_goals_mean_l5                      0.262338               0.275097
# away_goals_suf_mean                    -0.341899              -0.490568
# away_goals_suf_mean_l5                 -0.251401              -0.347995
# away_rank_mean                         -0.240708              -0.242154
# away_rank_mean_l5                      -0.175895              -0.172532
# away_points_mean                        0.226907               0.219080
# away_points_mean_l5                     0.111852               0.117675
# home_game_points_mean                  -0.448221              -0.351322
# home_game_points_mean_l5               -0.339159              -0.264851
# home_game_points_rank_mean             -0.351803              -0.244783
# home_game_points_rank_mean_l5          -0.235621              -0.164364
# away_game_points_mean                   0.404941               0.452648
# away_game_points_mean_l5                0.297515               0.328743
# away_game_points_rank_mean              0.317039               0.277993
# away_game_points_rank_mean_l5           0.192863               0.167076
# is_friendly_0                           0.063257               0.032062
# is_friendly_1                          -0.063257              -0.032062
# total_games_away                        0.139328               0.138451
# total_games_home                       -0.155738              -0.134987
# home_weight_goals                       1.000000               0.847062
# away_weight_goals_suf                   0.847062               1.000000
# home_weight_goals_l5                    0.928671               0.786140
# away_weight_goals_suf_l5                0.801815               0.937722
# home_weight_points                      0.978330               0.851526
# away_weight_points                      0.799079               0.686451
# away_weight_goals                       0.784602               0.686941
# home_weight_goals_suf                   0.683758               0.791791
# away_weight_goals_l5                    0.725873               0.644419
# home_weight_goals_suf_l5                0.648675               0.743831
#
#                                home_weight_goals_l5  away_weight_goals_suf_l5  \
# rank_home                                  0.447927                  0.412354
# rank_away                                 -0.446591                 -0.504135
# home_score                                -0.458419                 -0.450535
# away_score                                 0.350432                  0.362127
# result                                     0.303301                  0.290402
# rank_dif                                   0.840960                  0.861045
# rank_change_home                           0.036830                 -0.001544
# rank_change_away                          -0.012810                  0.001973
# home_goals_mean                           -0.388589                 -0.284052
# home_goals_mean_l5                        -0.398900                 -0.222016
# home_goals_suf_mean                        0.335939                  0.324319
# home_goals_suf_mean_l5                     0.259144                  0.246105
# home_rank_mean                             0.225364                  0.208725
# home_rank_mean_l5                          0.137067                  0.156419
# home_points_mean                          -0.266682                 -0.185906
# home_points_mean_l5                       -0.121915                 -0.075746
# away_goals_mean                            0.324859                  0.340198
# away_goals_mean_l5                         0.242213                  0.270383
# away_goals_suf_mean                       -0.321387                 -0.444577
# away_goals_suf_mean_l5                    -0.234510                 -0.386042
# away_rank_mean                            -0.222398                 -0.220629
# away_rank_mean_l5                         -0.166424                 -0.127790
# away_points_mean                           0.205207                  0.199006
# away_points_mean_l5                        0.101687                  0.116355
# home_game_points_mean                     -0.422465                 -0.339962
# home_game_points_mean_l5                  -0.357751                 -0.247908
# home_game_points_rank_mean                -0.319272                 -0.233952
# home_game_points_rank_mean_l5             -0.200669                 -0.158036
# away_game_points_mean                      0.373021                  0.419878
# away_game_points_mean_l5                   0.271249                  0.331958
# away_game_points_rank_mean                 0.297248                  0.266941
# away_game_points_rank_mean_l5              0.181212                  0.164765
# is_friendly_0                              0.056226                  0.031282
# is_friendly_1                             -0.056226                 -0.031282
# total_games_away                           0.107356                  0.129205
# total_games_home                          -0.165900                 -0.132847
# home_weight_goals                          0.928671                  0.801815
# away_weight_goals_suf                      0.786140                  0.937722
# home_weight_goals_l5                       1.000000                  0.743491
# away_weight_goals_suf_l5                   0.743491                  1.000000
# home_weight_points                         0.905468                  0.804326
# away_weight_points                         0.744413                  0.664448
# away_weight_goals                          0.732704                  0.662917
# home_weight_goals_suf                      0.640404                  0.766060
# away_weight_goals_l5                       0.680885                  0.595914
# home_weight_goals_suf_l5                   0.581000                  0.720597
#
#                                home_weight_points  away_weight_points  \
# rank_home                                0.480623            0.530865
# rank_away                               -0.499230           -0.445563
# home_score                              -0.490162           -0.403833
# away_score                               0.378314            0.448022
# result                                   0.327459            0.277453
# rank_dif                                 0.921063            0.918479
# rank_change_home                         0.031411            0.021780
# rank_change_away                        -0.006628           -0.001854
# home_goals_mean                         -0.369824           -0.401978
# home_goals_mean_l5                      -0.292821           -0.308310
# home_goals_suf_mean                      0.356328            0.425668
# home_goals_suf_mean_l5                   0.267454            0.341328
# home_rank_mean                           0.238930            0.236134
# home_rank_mean_l5                        0.173923            0.163213
# home_points_mean                        -0.278243           -0.281735
# home_points_mean_l5                     -0.113526           -0.106364
# away_goals_mean                          0.367371            0.317169
# away_goals_mean_l5                       0.273762            0.248182
# away_goals_suf_mean                     -0.341927           -0.259039
# away_goals_suf_mean_l5                  -0.247299           -0.186647
# away_rank_mean                          -0.246274           -0.262918
# away_rank_mean_l5                       -0.180944           -0.192306
# away_points_mean                         0.233213            0.214600
# away_points_mean_l5                      0.109685            0.100466
# home_game_points_mean                   -0.447394           -0.481950
# home_game_points_mean_l5                -0.334040           -0.356308
# home_game_points_rank_mean              -0.340464           -0.316405
# home_game_points_rank_mean_l5           -0.231484           -0.202864
# away_game_points_mean                    0.420283            0.354833
# away_game_points_mean_l5                 0.305467            0.259609
# away_game_points_rank_mean               0.329973            0.331910
# away_game_points_rank_mean_l5            0.205993            0.194782
# is_friendly_0                            0.065341            0.134418
# is_friendly_1                           -0.065341           -0.134418
# total_games_away                         0.143438            0.172664
# total_games_home                        -0.159803           -0.151128
# home_weight_goals                        0.978330            0.799079
# away_weight_goals_suf                    0.851526            0.686451
# home_weight_goals_l5                     0.905468            0.744413
# away_weight_goals_suf_l5                 0.804326            0.664448
# home_weight_points                       1.000000            0.816861
# away_weight_points                       0.816861            1.000000
# away_weight_goals                        0.794904            0.978329
# home_weight_goals_suf                    0.679821            0.853230
# away_weight_goals_l5                     0.735861            0.914802
# home_weight_goals_suf_l5                 0.646653            0.808578
#
#                                away_weight_goals  home_weight_goals_suf  \
# rank_home                               0.509974               0.536533
# rank_away                              -0.445710              -0.418371
# home_score                             -0.396206              -0.383013
# away_score                              0.454406               0.459494
# result                                  0.264672               0.240959
# rank_dif                                0.898848               0.898444
# rank_change_home                        0.019638               0.008700
# rank_change_away                        0.004756               0.016219
# home_goals_mean                        -0.385264              -0.368315
# home_goals_mean_l5                     -0.293821              -0.275052
# home_goals_suf_mean                     0.415224               0.493624
# home_goals_suf_mean_l5                  0.338003               0.394315
# home_rank_mean                          0.235360               0.233217
# home_rank_mean_l5                       0.160971               0.160923
# home_points_mean                       -0.271713              -0.230695
# home_points_mean_l5                    -0.105393              -0.089660
# away_goals_mean                         0.331958               0.280876
# away_goals_mean_l5                      0.259046               0.232431
# away_goals_suf_mean                    -0.273799              -0.300847
# away_goals_suf_mean_l5                 -0.198614              -0.214991
# away_rank_mean                         -0.265946              -0.228002
# away_rank_mean_l5                      -0.191940              -0.149983
# away_points_mean                        0.215196               0.166277
# away_points_mean_l5                     0.102407               0.096139
# home_game_points_mean                  -0.457542              -0.451914
# home_game_points_mean_l5               -0.340913              -0.328917
# home_game_points_rank_mean             -0.303344              -0.255298
# home_game_points_rank_mean_l5          -0.193034              -0.160676
# away_game_points_mean                   0.362592               0.328332
# away_game_points_mean_l5                0.267675               0.248212
# away_game_points_rank_mean              0.339496               0.249006
# away_game_points_rank_mean_l5           0.192805               0.131895
# is_friendly_0                           0.128619               0.093266
# is_friendly_1                          -0.128619              -0.093266
# total_games_away                        0.171668               0.158550
# total_games_home                       -0.141921              -0.130185
# home_weight_goals                       0.784602               0.683758
# away_weight_goals_suf                   0.686941               0.791791
# home_weight_goals_l5                    0.732704               0.640404
# away_weight_goals_suf_l5                0.662917               0.766060
# home_weight_points                      0.794904               0.679821
# away_weight_points                      0.978329               0.853230
# away_weight_goals                       1.000000               0.847733
# home_weight_goals_suf                   0.847733               1.000000
# away_weight_goals_l5                    0.933567               0.806706
# home_weight_goals_suf_l5                0.802296               0.940856
#
#                                away_weight_goals_l5  home_weight_goals_suf_l5
# rank_home                                  0.479948                  0.502666
# rank_away                                 -0.414676                 -0.399476
# home_score                                -0.371386                 -0.356446
# away_score                                 0.424451                  0.432623
# result                                     0.248603                  0.225213
# rank_dif                                   0.841451                  0.848751
# rank_change_home                           0.017961                  0.001375
# rank_change_away                           0.005851                  0.025041
# home_goals_mean                           -0.359938                 -0.344274
# home_goals_mean_l5                        -0.275356                 -0.253169
# home_goals_suf_mean                        0.399085                  0.462438
# home_goals_suf_mean_l5                     0.317419                  0.402999
# home_rank_mean                             0.218149                  0.219749
# home_rank_mean_l5                          0.154632                  0.141407
# home_points_mean                          -0.248779                 -0.220263
# home_points_mean_l5                       -0.096102                 -0.076056
# away_goals_mean                            0.305070                  0.273377
# away_goals_mean_l5                         0.248640                  0.219014
# away_goals_suf_mean                       -0.257571                 -0.277794
# away_goals_suf_mean_l5                    -0.169666                 -0.202968
# away_rank_mean                            -0.249050                 -0.217960
# away_rank_mean_l5                         -0.187218                 -0.150562
# away_points_mean                           0.206993                  0.167700
# away_points_mean_l5                        0.090020                  0.085048
# home_game_points_mean                     -0.429254                 -0.424203
# home_game_points_mean_l5                  -0.316698                 -0.297277
# home_game_points_rank_mean                -0.277679                 -0.247144
# home_game_points_rank_mean_l5             -0.178744                 -0.162316
# away_game_points_mean                      0.333232                  0.313334
# away_game_points_mean_l5                   0.229072                  0.229264
# away_game_points_rank_mean                 0.311747                  0.234674
# away_game_points_rank_mean_l5              0.168450                  0.119638
# is_friendly_0                              0.122843                  0.085672
# is_friendly_1                             -0.122843                 -0.085672
# total_games_away                           0.185978                  0.160521
# total_games_home                          -0.103590                 -0.117827
# home_weight_goals                          0.725873                  0.648675
# away_weight_goals_suf                      0.644419                  0.743831
# home_weight_goals_l5                       0.680885                  0.581000
# away_weight_goals_suf_l5                   0.595914                  0.720597
# home_weight_points                         0.735861                  0.646653
# away_weight_points                         0.914802                  0.808578
# away_weight_goals                          0.933567                  0.802296
# home_weight_goals_suf                      0.806706                  0.940856
# away_weight_goals_l5                       1.000000                  0.762649
# home_weight_goals_suf_l5                   0.762649                  1.000000
#
# [46 rows x 46 columns]
